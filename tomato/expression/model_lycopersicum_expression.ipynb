# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import ExtraTreesRegressor
import shap
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model

# %%
model = ExtraTreesRegressor(random_state=1)

# %% [markdown]
# # Loading Data

# %%
study = pd.read_csv('./input/lycopersicum_expression.csv')

# Smoothing crossovers
study['crossovers'] = study['crossovers'].astype(float)
study['scrossovers'] = 0 
for i in range (1, len(study)):
    if study.loc[i-1,'chr'] == study.loc[i,'chr']:
        study['scrossovers'] = gaussian_filter(study['crossovers'], sigma= 3)
        
study.head()
# Out:
#                            cross     reference   chr   start     end  \
# 0  lycopersicum_pimpinellifolium  lycopersicum  chr1       0  100000
# 1  lycopersicum_pimpinellifolium  lycopersicum  chr1  100000  200000
# 2  lycopersicum_pimpinellifolium  lycopersicum  chr1  200000  300000
# 3  lycopersicum_pimpinellifolium  lycopersicum  chr1  300000  400000
# 4  lycopersicum_pimpinellifolium  lycopersicum  chr1  400000  500000
#
#    crossovers  gene  mRNA  exon  CDS  scrossovers
# 0         0.0    15    15    84   81     0.412753
# 1         0.0    12    12    49   44     0.423919
# 2         1.0    16    16   105  104     0.437421
# 3         1.0    15    15    67   63     0.442235
# 4         1.0    17    17    70   64     0.433930

# %% [markdown]
# # Data exploration

# %%
df = study

df_stats = df.drop(['cross','reference','chr', 'start', 'end', 'scrossovers'],  axis=1)
df_stats_corr = df_stats.corr()['crossovers'].sort_values(ascending = True)
df_corr = df_stats.corr()
df_corr = df_corr.iloc[1:, :]
fig = plt.figure(figsize=(15,9))
ax = fig.add_subplot(111)
df_corr['crossovers'].sort_values(ascending = True).plot(kind = 'bar', color='skyblue', edgecolor='black')
ax.set_xlabel('Expression elements', fontsize=20)
ax.set_ylabel('Correlation with CO frequency', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=14)
plt.suptitle('S. lycopersicum', fontsize=25)
plt.subplots_adjust(top=0.92)
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(df_stats.corr(), cmap= 'coolwarm', linewidths = 0.5, linecolor='white')
plt.show()

# %% [markdown]
# # Chromosome Split

# %%
# Objects with chromosome info
chr1 = df[df['chr']== 'chr1']
chr2 = df[df['chr']== 'chr2']
chr3 = df[df['chr']== 'chr3']
chr4 = df[df['chr']== 'chr4']
chr5 = df[df['chr']== 'chr5']
chr6 = df[df['chr']== 'chr6']
chr7 = df[df['chr']== 'chr7']
chr8 = df[df['chr']== 'chr8']
chr9 = df[df['chr']== 'chr9']
chr10 = df[df['chr']== 'chr10']
chr11 = df[df['chr']== 'chr11']
chr12 = df[df['chr']== 'chr12']

# %%
# Objects with information of all chromosomes except the target chromosome.
achr1 = df[df['chr']!= 'chr1']
achr2 = df[df['chr']!= 'chr2']
achr3 = df[df['chr']!= 'chr3']
achr4 = df[df['chr']!= 'chr4']
achr5 = df[df['chr']!= 'chr5']
achr6 = df[df['chr']!= 'chr6']
achr7 = df[df['chr']!= 'chr7']
achr8 = df[df['chr']!= 'chr8']
achr9 = df[df['chr']!= 'chr9']
achr10 = df[df['chr']!= 'chr10']
achr11 = df[df['chr']!= 'chr11']
achr12 = df[df['chr']!= 'chr12']

# %% [markdown]
# # Function to train models and make graphs

# %% [markdown]
# The model is trained with the information of all chromosomes except the information of the chromosome to be predicted.

# %%
def plot_chromosome_results(chr_number):
    # Replace  with 'chr{chr_number}' 
    chromosomes_data = globals()[f'achr{chr_number}']
    chr_data = globals()[f'chr{chr_number}']

    # TRAINING MODEL
    X_train = chromosomes_data.drop(['cross','reference','chr', 'start', 'end','crossovers','scrossovers'], axis=1)
    y_train = chromosomes_data[['crossovers']]

    model.fit(X_train, y_train)
    model_preds = model.predict(chr_data.drop(['cross','reference','chr', 'start', 'end','crossovers','scrossovers'], axis=1))
    
    #SMOOTHING
    model_preds = pd.DataFrame(model_preds, columns=['model_preds']) 
    model_spreds = gaussian_filter(model_preds['model_preds'], sigma= 3)
        
    #CORRELATIONS BY QUARTILES
    c_q1 = int(len(chr_data)*0.25)
    c_q2 = int(len(chr_data)*0.50)
    c_q3 = int(len(chr_data)*0.75)
    
    rq1 = chr_data['scrossovers'].iloc[0:c_q1]
    rq2 = chr_data['scrossovers'].iloc[c_q1:c_q2]
    rq3 = chr_data['scrossovers'].iloc[c_q2:c_q3]
    rq4 = chr_data['scrossovers'].iloc[c_q3:int(len(chr_data))]

    pq1 = model_spreds[0:c_q1]
    pq2 = model_spreds[c_q1:c_q2]
    pq3 = model_spreds[c_q2:c_q3]
    pq4 = model_spreds[c_q3:int(len(chr_data))]

    corr_q1 = np.corrcoef(rq1, pq1)[0, 1]
    corr_q2 = np.corrcoef(rq2, pq2)[0, 1]
    corr_q3 = np.corrcoef(rq3, pq3)[0, 1]
    corr_q4 = np.corrcoef(rq4, pq4)[0, 1]
    
    globals()[f'corr_q1_chr{chr_number}'] = corr_q1
    globals()[f'corr_q2_chr{chr_number}'] = corr_q2
    globals()[f'corr_q3_chr{chr_number}'] = corr_q3
    globals()[f'corr_q4_chr{chr_number}'] = corr_q4
     
    # PLOTTING RESULTS
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4), gridspec_kw={'width_ratios': [10, 3]})

    # Line plot and correlation plot
    ax1.plot(chr_data.end, chr_data.scrossovers, label='Crossovers')
    ax1.plot(chr_data.end, model_spreds, label='Prediction', color='green')
    ax1.set_title(f'S. lycopersicum Chromosome {chr_number}', fontsize=20)
    ax1.set_xlabel('Chromosome position (Mb)', fontsize=15)
    ax1.set_ylabel('CO frequency (100kb)', fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ticks = ax1.get_xticks() / 1000000
    ax1.set_xticklabels(ticks)
        
    chr_len = chr_data["end"].iloc[-1]
    q1 =round(chr_len * 0.25 / 100000) * 100000
    q2 =round(chr_len* 0.50 / 100000) * 100000
    q3 =round(chr_len * 0.75 / 100000) * 100000

    ax1.axvline(x=q1, color='gray', linestyle='-')
    ax1.axvline(x=q2, color='gray', linestyle='--')
    ax1.axvline(x=q3, color='gray', linestyle='-')

    # Scatter plot
    scatter = ax2.scatter(chr_data.scrossovers, model_spreds, c='skyblue', edgecolors='black', linewidth= 0.3)
    ax2.set_title('Observed  vs. Expected', fontsize=15)
    ax2.set_xlabel('Observed ', fontsize=15)
    ax2.set_ylabel('Expected', fontsize=15)

    # Calculate correlation coefficient, coefficient of determination, and Mean Squared Error
    corr_chr = np.corrcoef(chr_data.scrossovers, model_spreds)[0, 1]
    r2_chr = r2_score(chr_data.scrossovers, model_spreds)
    mse_chr = mean_squared_error(chr_data.scrossovers, model_spreds)

    # Calculate the aspect ratio based on the plot heights
    h1 = ax1.get_ylim()
    h2 = ax2.get_ylim()
    aspect_ratio = max(h1[1] - h1[0], h2[1] - h2[0]) / (max(h1[1], h2[1]) - min(h1[0], h2[0]))

    # Set the aspect ratio for the scatter plot only if it doesn't distort the square shape
    if aspect_ratio < 1:
        ax2.set_aspect('equal')

    # Display correlation coefficient, coefficient of determination, and Mean Squared Error as plain text
    globals()[f'corr_chr{chr_number}'] = corr_chr
    globals()[f'r2_chr{chr_number}'] = r2_chr
    globals()[f'mse_chr{chr_number}'] = mse_chr

    textstr = f'Correlation: {corr_chr:.3f}\nR-squared: {r2_chr:.3f}\nMSE: {mse_chr:.3f}'
    ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=12, verticalalignment='top', horizontalalignment='left')

    # Adjustments to align the heights of the two plots
    max_height = max(h1[1], h2[1])
    ax1.set_ylim([h1[0], max_height])
    ax2.set_ylim([h2[0], max_height])

    # Reduce the separation between the plots
    plt.subplots_adjust(wspace=0.13)
    plt.show()

# %%
# Predictions and graphs for all chromosomes
for chr_number in range(1, 13):
    plot_chromosome_results(chr_number)
    plt.show()

# %% [markdown]
# # Data compilation

# %%
corr = pd.DataFrame({'corr':[corr_chr1, corr_chr2, corr_chr3, corr_chr4, corr_chr5, corr_chr6,corr_chr7, corr_chr8, corr_chr9, corr_chr10, corr_chr11, corr_chr12]})
r2 = pd.DataFrame({'R^2':[r2_chr1, r2_chr2, r2_chr3, r2_chr4, r2_chr5, r2_chr6, r2_chr7, r2_chr8, r2_chr9, r2_chr10, r2_chr11, r2_chr12]})
mse = pd.DataFrame({'MSE':[mse_chr1, mse_chr2, mse_chr3, mse_chr4, mse_chr5, mse_chr6, mse_chr7, mse_chr8, mse_chr9, mse_chr10, mse_chr11, mse_chr12]})
index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9','chr10','chr11','chr12']})
table = pd.concat([index, corr, r2, mse], axis=1)
table
# Out:
#       chr      corr       R^2       MSE
# 0    chr1  0.666591  0.412339  0.022547
# 1    chr2  0.665411 -0.636768  0.034288
# 2    chr3  0.657582  0.411004  0.022451
# 3    chr4  0.637890  0.395985  0.026005
# 4    chr5  0.731006  0.490160  0.016744
# 5    chr6  0.666445  0.247050  0.027507
# 6    chr7  0.614772  0.356297  0.033245
# 7    chr8  0.829363  0.670294  0.012757
# 8    chr9  0.775077  0.547788  0.025140
# 9   chr10  0.716689  0.503039  0.020364
# 10  chr11  0.575612  0.316228  0.033372
# 11  chr12  0.734635  0.391990  0.047206

# %% [markdown]
# # Correlations between predictions and original values by chromosome quartiles

# %%
corr_q1 = pd.DataFrame({'Q1':[corr_q1_chr1,corr_q1_chr2,corr_q1_chr3,corr_q1_chr4,corr_q1_chr5,corr_q1_chr6,corr_q1_chr7,corr_q1_chr8,corr_q1_chr9,corr_q1_chr10,corr_q1_chr11,corr_q1_chr12]})
corr_q2 = pd.DataFrame({'Q2':[corr_q2_chr1,corr_q2_chr2,corr_q2_chr3,corr_q2_chr4,corr_q2_chr5,corr_q2_chr6,corr_q2_chr7,corr_q2_chr8,corr_q2_chr9,corr_q2_chr10,corr_q2_chr11,corr_q2_chr12]})
corr_q3 = pd.DataFrame({'Q3':[corr_q3_chr1,corr_q3_chr2,corr_q3_chr3,corr_q3_chr4,corr_q3_chr5,corr_q3_chr6,corr_q3_chr7,corr_q3_chr8,corr_q3_chr9,corr_q3_chr10,corr_q3_chr11,corr_q3_chr12]})
corr_q4 = pd.DataFrame({'Q4':[corr_q4_chr1,corr_q4_chr2,corr_q4_chr3,corr_q4_chr4,corr_q4_chr5,corr_q4_chr6,corr_q4_chr7,corr_q4_chr8,corr_q4_chr9,corr_q4_chr10,corr_q4_chr11,corr_q4_chr12]})

index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9','chr10','chr11','chr12']})
q_corr = pd.concat([index, corr_q1, corr_q2, corr_q3, corr_q4], axis=1)
q_corr_styled = q_corr.style.background_gradient(cmap="PRGn", vmin=-1, vmax=1)
q_corr_styled.set_table_styles([{'selector': 'th',
                                'props': [('text-align', 'center')]}])
q_corr_styled
# Out:
# <style type="text/css">
# #T_53b0c th {
#   text-align: center;
# }
# #T_53b0c_row0_col1, #T_53b0c_row5_col1 {
#   background-color: #328c47;
#   color: #f1f1f1;
# }
# #T_53b0c_row0_col2 {
#   background-color: #e1f2dd;
#   color: #000000;
# }
# #T_53b0c_row0_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_53b0c_row0_col4 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_53b0c_row1_col1, #T_53b0c_row11_col2 {
#   background-color: #e8d7e9;
#   color: #000000;
# }
# #T_53b0c_row1_col2 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_53b0c_row1_col3 {
#   background-color: #63b368;
#   color: #f1f1f1;
# }
# #T_53b0c_row1_col4 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_53b0c_row2_col1 {
#   background-color: #1a7736;
#   color: #f1f1f1;
# }
# #T_53b0c_row2_col2 {
#   background-color: #bde4b7;
#   color: #000000;
# }
# #T_53b0c_row2_col3, #T_53b0c_row4_col2 {
#   background-color: #b3e0ad;
#   color: #000000;
# }
# #T_53b0c_row2_col4 {
#   background-color: #96d192;
#   color: #000000;
# }
# #T_53b0c_row3_col1 {
#   background-color: #308a45;
#   color: #f1f1f1;
# }
# #T_53b0c_row3_col2 {
#   background-color: #c6aad1;
#   color: #000000;
# }
# #T_53b0c_row3_col3 {
#   background-color: #eef5ec;
#   color: #000000;
# }
# #T_53b0c_row3_col4 {
#   background-color: #f3f6f2;
#   color: #000000;
# }
# #T_53b0c_row4_col1 {
#   background-color: #58ac5f;
#   color: #f1f1f1;
# }
# #T_53b0c_row4_col3 {
#   background-color: #eff5ee;
#   color: #000000;
# }
# #T_53b0c_row4_col4 {
#   background-color: #12672e;
#   color: #f1f1f1;
# }
# #T_53b0c_row5_col2 {
#   background-color: #dec9e2;
#   color: #000000;
# }
# #T_53b0c_row5_col3 {
#   background-color: #55aa5e;
#   color: #f1f1f1;
# }
# #T_53b0c_row5_col4 {
#   background-color: #b5e1af;
#   color: #000000;
# }
# #T_53b0c_row6_col1 {
#   background-color: #37904a;
#   color: #f1f1f1;
# }
# #T_53b0c_row6_col2 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_53b0c_row6_col3 {
#   background-color: #c4a8d0;
#   color: #000000;
# }
# #T_53b0c_row6_col4 {
#   background-color: #6fba72;
#   color: #f1f1f1;
# }
# #T_53b0c_row7_col1 {
#   background-color: #075223;
#   color: #f1f1f1;
# }
# #T_53b0c_row7_col2 {
#   background-color: #e5f3e1;
#   color: #000000;
# }
# #T_53b0c_row7_col3, #T_53b0c_row11_col3 {
#   background-color: #dbc5e0;
#   color: #000000;
# }
# #T_53b0c_row7_col4 {
#   background-color: #81c581;
#   color: #000000;
# }
# #T_53b0c_row8_col1, #T_53b0c_row11_col1 {
#   background-color: #177133;
#   color: #f1f1f1;
# }
# #T_53b0c_row8_col2 {
#   background-color: #f3eef3;
#   color: #000000;
# }
# #T_53b0c_row8_col3 {
#   background-color: #f0e7f0;
#   color: #000000;
# }
# #T_53b0c_row8_col4 {
#   background-color: #3a924c;
#   color: #f1f1f1;
# }
# #T_53b0c_row9_col1 {
#   background-color: #1c7938;
#   color: #f1f1f1;
# }
# #T_53b0c_row9_col2 {
#   background-color: #9cd597;
#   color: #000000;
# }
# #T_53b0c_row9_col3 {
#   background-color: #a5da9f;
#   color: #000000;
# }
# #T_53b0c_row9_col4 {
#   background-color: #499f55;
#   color: #f1f1f1;
# }
# #T_53b0c_row10_col1, #T_53b0c_row10_col4 {
#   background-color: #8dcc8b;
#   color: #000000;
# }
# #T_53b0c_row10_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_53b0c_row10_col3 {
#   background-color: #e9d8ea;
#   color: #000000;
# }
# #T_53b0c_row11_col4 {
#   background-color: #72bc75;
#   color: #000000;
# }
# </style>
# <table id="T_53b0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53b0c_level0_col0" class="col_heading level0 col0" >chr</th>
#       <th id="T_53b0c_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_53b0c_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_53b0c_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_53b0c_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53b0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53b0c_row0_col0" class="data row0 col0" >chr1</td>
#       <td id="T_53b0c_row0_col1" class="data row0 col1" >0.723285</td>
#       <td id="T_53b0c_row0_col2" class="data row0 col2" >0.144077</td>
#       <td id="T_53b0c_row0_col3" class="data row0 col3" >0.200172</td>
#       <td id="T_53b0c_row0_col4" class="data row0 col4" >0.242060</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53b0c_row1_col0" class="data row1 col0" >chr2</td>
#       <td id="T_53b0c_row1_col1" class="data row1 col1" >-0.181732</td>
#       <td id="T_53b0c_row1_col2" class="data row1 col2" >0.205228</td>
#       <td id="T_53b0c_row1_col3" class="data row1 col3" >0.577396</td>
#       <td id="T_53b0c_row1_col4" class="data row1 col4" >0.232811</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_53b0c_row2_col0" class="data row2 col0" >chr3</td>
#       <td id="T_53b0c_row2_col1" class="data row2 col1" >0.800560</td>
#       <td id="T_53b0c_row2_col2" class="data row2 col2" >0.308389</td>
#       <td id="T_53b0c_row2_col3" class="data row2 col3" >0.345091</td>
#       <td id="T_53b0c_row2_col4" class="data row2 col4" >0.444160</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_53b0c_row3_col0" class="data row3 col0" >chr4</td>
#       <td id="T_53b0c_row3_col1" class="data row3 col1" >0.733454</td>
#       <td id="T_53b0c_row3_col2" class="data row3 col2" >-0.376517</td>
#       <td id="T_53b0c_row3_col3" class="data row3 col3" >0.056282</td>
#       <td id="T_53b0c_row3_col4" class="data row3 col4" >0.026808</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_53b0c_row4_col0" class="data row4 col0" >chr5</td>
#       <td id="T_53b0c_row4_col1" class="data row4 col1" >0.602643</td>
#       <td id="T_53b0c_row4_col2" class="data row4 col2" >0.348918</td>
#       <td id="T_53b0c_row4_col3" class="data row4 col3" >0.050055</td>
#       <td id="T_53b0c_row4_col4" class="data row4 col4" >0.862142</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_53b0c_row5_col0" class="data row5 col0" >chr6</td>
#       <td id="T_53b0c_row5_col1" class="data row5 col1" >0.723844</td>
#       <td id="T_53b0c_row5_col2" class="data row5 col2" >-0.247076</td>
#       <td id="T_53b0c_row5_col3" class="data row5 col3" >0.614038</td>
#       <td id="T_53b0c_row5_col4" class="data row5 col4" >0.336015</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_53b0c_row6_col0" class="data row6 col0" >chr7</td>
#       <td id="T_53b0c_row6_col1" class="data row6 col1" >0.709277</td>
#       <td id="T_53b0c_row6_col2" class="data row6 col2" >0.388860</td>
#       <td id="T_53b0c_row6_col3" class="data row6 col3" >-0.387027</td>
#       <td id="T_53b0c_row6_col4" class="data row6 col4" >0.546282</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_53b0c_row7_col0" class="data row7 col0" >chr8</td>
#       <td id="T_53b0c_row7_col1" class="data row7 col1" >0.937906</td>
#       <td id="T_53b0c_row7_col2" class="data row7 col2" >0.117823</td>
#       <td id="T_53b0c_row7_col3" class="data row7 col3" >-0.262113</td>
#       <td id="T_53b0c_row7_col4" class="data row7 col4" >0.493295</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_53b0c_row8_col0" class="data row8 col0" >chr9</td>
#       <td id="T_53b0c_row8_col1" class="data row8 col1" >0.822480</td>
#       <td id="T_53b0c_row8_col2" class="data row8 col2" >-0.050306</td>
#       <td id="T_53b0c_row8_col3" class="data row8 col3" >-0.087745</td>
#       <td id="T_53b0c_row8_col4" class="data row8 col4" >0.698443</td>
#     </tr>
#     <tr>
#       <th id="T_53b0c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_53b0c_row9_col0" class="data row9 col0" >chr10</td>
#       <td id="T_53b0c_row9_col1" class="data row9 col1" >0.791849</td>
#       <td id="T_53b0c_row9_col2" class="data row9 col2" >0.423982</td>
#       <td id="T_53b0c_row9_col3" class="data row9 col3" >0.

# %% [markdown]
# # Save model performance metrics

# %%
table.to_csv('./output/model_lycopersicum_expression.csv', index = None)

# %% [markdown]
# # Shap values (Features contribution)

# %% [markdown]
# This analysis can take hours in some cases. If it takes too long, we recommend adapting the code to run on a server.

# %%
X = df.drop(['cross','reference','chr', 'start', 'end','crossovers','scrossovers'], axis=1)
y = df[['scrossovers']]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

model = ExtraTreesRegressor(random_state=1)
model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=1)

# %%
X_frame = pd.DataFrame(data=X)
explainer = shap.Explainer(model)
shap_values = explainer(X_frame)
shap.plots.bar(shap_values)

# %%
# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])

# %%
# summarize the effects of all the features
shap.plots.beeswarm(shap_values)
