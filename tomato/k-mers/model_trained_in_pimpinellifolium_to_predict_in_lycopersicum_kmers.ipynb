# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import ExtraTreesRegressor
import shap
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model

# %%
model = ExtraTreesRegressor(random_state=1)

# %% [markdown]
# # Loading Data

# %%
lycopersicum = pd.read_csv('./input/lycopersicum_kmers.csv')

# Smoothing crossovers
lycopersicum['crossovers'] = lycopersicum['crossovers'].astype(float)
lycopersicum['scrossovers'] = 0 
for i in range (1, len(lycopersicum)):
    if lycopersicum.loc[i-1,'chr'] == lycopersicum.loc[i,'chr']:
        lycopersicum['scrossovers'] = gaussian_filter(lycopersicum['crossovers'], sigma= 3)
        
lycopersicum.head()
# Out:
#                            cross     reference   chr   start     end  \
# 0  lycopersicum_pimpinellifolium  lycopersicum  chr1       0  100000
# 1  lycopersicum_pimpinellifolium  lycopersicum  chr1  100000  200000
# 2  lycopersicum_pimpinellifolium  lycopersicum  chr1  200000  300000
# 3  lycopersicum_pimpinellifolium  lycopersicum  chr1  300000  400000
# 4  lycopersicum_pimpinellifolium  lycopersicum  chr1  400000  500000
#
#    crossovers   AAA   AAC   AAG   AAT  ...   TCT   TGA   TGC   TGG   TGT  \
# 0         0.0  5131  1569  1987  3622  ...  1777  1910  1054  1213  1916
# 1         0.0  5725  1659  2040  4200  ...  1868  2032   819  1146  1876
# 2         1.0  5181  1848  2007  3773  ...  1907  2047   980  1070  1961
# 3         1.0  5201  1733  2091  3889  ...  1848  2029   904  1066  2039
# 4         1.0  5715  1862  1882  4043  ...  2006  2032   871  1039  1791
#
#     TTA   TTC   TTG   TTT  scrossovers
# 0  2815  2175  2456  5659     0.412753
# 1  3503  2030  2404  5689     0.423919
# 2  3330  2039  2373  5368     0.437421
# 3  3417  2071  2383  5501     0.442235
# 4  3345  2244  2294  5618     0.433930
#
# [5 rows x 71 columns]

# %%
pimpinellifolium = pd.read_csv('./input/pimpinellifolium_kmers.csv')

# Smoothing crossovers
pimpinellifolium['crossovers'] = pimpinellifolium['crossovers'].astype(float)
pimpinellifolium['scrossovers'] = 0 
for i in range (1, len(pimpinellifolium)):
    if pimpinellifolium.loc[i-1,'chr'] == pimpinellifolium.loc[i,'chr']:
        pimpinellifolium['scrossovers'] = gaussian_filter(pimpinellifolium['crossovers'], sigma= 3)
        
pimpinellifolium.head()
# Out:
#                            cross         reference   chr   start     end  \
# 0  lycopersicum_pimpinellifolium  pimpinellifolium  chr1       0  100000
# 1  lycopersicum_pimpinellifolium  pimpinellifolium  chr1  100000  200000
# 2  lycopersicum_pimpinellifolium  pimpinellifolium  chr1  200000  300000
# 3  lycopersicum_pimpinellifolium  pimpinellifolium  chr1  300000  400000
# 4  lycopersicum_pimpinellifolium  pimpinellifolium  chr1  400000  500000
#
#    crossovers   AAA   AAC   AAG   AAT  ...   TCT   TGA   TGC   TGG   TGT  \
# 0         0.0  5213  1597  1969  3659  ...  1790  1909  1033  1200  1921
# 1         0.0  5319  1676  2115  3751  ...  1882  1983   904  1233  1851
# 2         1.0  4196  1547  1977  2831  ...  1582  1673  1200  1448  1906
# 3         0.0  5595  1641  1947  4143  ...  1804  2021   817   960  1937
# 4         0.0  5430  1850  2017  3861  ...  1911  2018   938  1070  1889
#
#     TTA   TTC   TTG   TTT  scrossovers
# 0  2852  2177  2438  5676     0.240383
# 1  3110  2003  2392  5021     0.248206
# 2  2203  2097  2482  5415     0.260576
# 3  3793  1995  2360  5920     0.273225
# 4  3252  2115  2275  5508     0.283863
#
# [5 rows x 71 columns]

# %% [markdown]
# # Reverse-complements count

# %%
df_original = lycopersicum
df_new = df_original[['cross','reference','chr', 'start', 'end','crossovers','scrossovers']].copy()

# List of complementary trimers
complementaries = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}

# Set to track processed trimers
processed = set()

# Iterate over the columns of the original DataFrame
for column in df_original.columns[9:-1]:  # Starts from where kmers start
    trimer = column[:3]  # Get the current trimer (e.g., 'AAA')
    
    # Avoid processing the same trimer more than once
    if trimer not in processed:
        complementary = ''.join([complementaries[base] for base in reversed(trimer)])  # Get the complementary trimer (e.g., 'TTT')
        
        # Sum the corresponding columns and add a new column to the new DataFrame
        df_new[trimer + '_' + complementary] = df_original[trimer] + df_original[complementary]
        
        # Add the trimer and its complementary to the set of processed trimers
        processed.add(trimer)
        processed.add(complementary)
        
lycopersicum2 = df_new

# %%
lycopersicum2.head()
# Out:
#                            cross     reference   chr   start     end  \
# 0  lycopersicum_pimpinellifolium  lycopersicum  chr1       0  100000
# 1  lycopersicum_pimpinellifolium  lycopersicum  chr1  100000  200000
# 2  lycopersicum_pimpinellifolium  lycopersicum  chr1  200000  300000
# 3  lycopersicum_pimpinellifolium  lycopersicum  chr1  300000  400000
# 4  lycopersicum_pimpinellifolium  lycopersicum  chr1  400000  500000
#
#    crossovers  scrossovers  AAT_ATT  ACA_TGT  ACC_GGT  ...  GAA_TTC  GAC_GTC  \
# 0         0.0     0.412753     7568     3819     1844  ...     4060     2062
# 1         0.0     0.423919     8318     3774     1539  ...     4179     1499
# 2         1.0     0.437421     7701     3911     1597  ...     4123     1535
# 3         1.0     0.442235     7897     3977     1714  ...     4192     1490
# 4         1.0     0.433930     8123     3755     1674  ...     4223     1444
#
#    GCA_TGC  GCC_GGC  GGA_TCC  GTA_TAC  GTT_AAC  TAA_TTA  TCA_TGA  TTT_AAA
# 0     2138     1120     2238     2486     3101     5684     4066    10790
# 1     1592      861     1966     2530     3443     6986     4115    11414
# 2     1950      828     2037     2651     3615     6559     4143    10549
# 3     1886      747     1916     2682     3540     6740     4105    10702
# 4     1731      771     1971     2573     3527     6707     4175    11333
#
# [5 rows x 39 columns]

# %%
df_original = pimpinellifolium
df_new = df_original[['cross','reference','chr', 'start', 'end','crossovers','scrossovers']].copy()

# List of complementary trimers
complementaries = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}

# Set to track processed trimers
processed = set()

# Iterate over the columns of the original DataFrame
for column in df_original.columns[9:-1]:  # Starts from where kmers start
    trimer = column[:3]  # Get the current trimer (e.g., 'AAA')
    
    # Avoid processing the same trimer more than once
    if trimer not in processed:
        complementary = ''.join([complementaries[base] for base in reversed(trimer)])  # Get the complementary trimer (e.g., 'TTT')
        
        # Sum the corresponding columns and add a new column to the new DataFrame
        df_new[trimer + '_' + complementary] = df_original[trimer] + df_original[complementary]
        
        # Add the trimer and its complementary to the set of processed trimers
        processed.add(trimer)
        processed.add(complementary)
        
pimpinellifolium2 = df_new

# %%
pimpinellifolium2.head()
# Out:
#                            cross         reference   chr   start     end  \
# 0  lycopersicum_pimpinellifolium  pimpinellifolium  chr1       0  100000
# 1  lycopersicum_pimpinellifolium  pimpinellifolium  chr1  100000  200000
# 2  lycopersicum_pimpinellifolium  pimpinellifolium  chr1  200000  300000
# 3  lycopersicum_pimpinellifolium  pimpinellifolium  chr1  300000  400000
# 4  lycopersicum_pimpinellifolium  pimpinellifolium  chr1  400000  500000
#
#    crossovers  scrossovers  AAT_ATT  ACA_TGT  ACC_GGT  ...  GAA_TTC  GAC_GTC  \
# 0         0.0     0.240383     7606     3834     1829  ...     4055     1998
# 1         0.0     0.248206     7397     3679     1721  ...     4223     1759
# 2         1.0     0.260576     6317     3586     2192  ...     3908     2733
# 3         0.0     0.273225     8472     4136     1526  ...     3982     1400
# 4         0.0     0.283863     7707     3916     1749  ...     4247     1521
#
#    GCA_TGC  GCC_GGC  GGA_TCC  GTA_TAC  GTT_AAC  TAA_TTA  TCA_TGA  TTT_AAA
# 0     2092     1137     2221     2481     3123     5771     4049    10889
# 1     1757     1166     2205     2414     3518     6160     4016    10340
# 2     2432     1524     2633     2363     3076     4322     4003     9611
# 3     1643      707     1757     2556     3436     7432     4010    11515
# 4     1917      807     1971     2660     3500     6405     4129    10938
#
# [5 rows x 39 columns]

# %% [markdown]
# # Model training

# %%
# Training model with pimpinellifolium reverse complementary k-mers
df = pimpinellifolium2
X_train = df.drop(['cross','reference','chr', 'start', 'end','crossovers','scrossovers'], axis=1)
y_train = df[['crossovers']]
model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=1)

# %% [markdown]
# # Chromosome Split

# %%
# Objects with chromosome data from lycopersicum
df = lycopersicum2
chr1 = df[df['chr']== 'chr1']
chr2 = df[df['chr']== 'chr2']
chr3 = df[df['chr']== 'chr3']
chr4 = df[df['chr']== 'chr4']
chr5 = df[df['chr']== 'chr5']
chr6 = df[df['chr']== 'chr6']
chr7 = df[df['chr']== 'chr7']
chr8 = df[df['chr']== 'chr8']
chr9 = df[df['chr']== 'chr9']
chr10 = df[df['chr']== 'chr10']
chr11 = df[df['chr']== 'chr11']
chr12 = df[df['chr']== 'chr12']

# %% [markdown]
# # Function to make predictions and graphs

# %% [markdown]
# The model is trained with the information of all chromosomes except the information of the chromosome to be predicted.

# %%
def plot_chromosome_results(chr_number):
    # Replace  with 'chr{chr_number}' 
    chr_data = globals()[f'chr{chr_number}']

    # MODEL PREDICTIONS
    model_preds = model.predict(chr_data.drop(['cross','reference','chr', 'start', 'end','crossovers','scrossovers'], axis=1))
    
    #SMOOTHING
    model_preds = pd.DataFrame(model_preds, columns=['model_preds']) 
    model_spreds = gaussian_filter(model_preds['model_preds'], sigma= 3)
        
    #CORRELATIONS BY QUARTILES
    c_q1 = int(len(chr_data)*0.25)
    c_q2 = int(len(chr_data)*0.50)
    c_q3 = int(len(chr_data)*0.75)
    
    rq1 = chr_data['scrossovers'].iloc[0:c_q1]
    rq2 = chr_data['scrossovers'].iloc[c_q1:c_q2]
    rq3 = chr_data['scrossovers'].iloc[c_q2:c_q3]
    rq4 = chr_data['scrossovers'].iloc[c_q3:int(len(chr_data))]

    pq1 = model_spreds[0:c_q1]
    pq2 = model_spreds[c_q1:c_q2]
    pq3 = model_spreds[c_q2:c_q3]
    pq4 = model_spreds[c_q3:int(len(chr_data))]

    corr_q1 = np.corrcoef(rq1, pq1)[0, 1]
    corr_q2 = np.corrcoef(rq2, pq2)[0, 1]
    corr_q3 = np.corrcoef(rq3, pq3)[0, 1]
    corr_q4 = np.corrcoef(rq4, pq4)[0, 1]
    
    globals()[f'corr_q1_chr{chr_number}'] = corr_q1
    globals()[f'corr_q2_chr{chr_number}'] = corr_q2
    globals()[f'corr_q3_chr{chr_number}'] = corr_q3
    globals()[f'corr_q4_chr{chr_number}'] = corr_q4
     
    # PLOTTING RESULTS
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4), gridspec_kw={'width_ratios': [10, 3]})

    # Line plot and correlation plot
    ax1.plot(chr_data.end, chr_data.scrossovers, label='Crossovers')
    ax1.plot(chr_data.end, model_spreds, label='Prediction', color='green')
    ax1.set_title(f'S. lycopersicum Chromosome {chr_number}', fontsize=20)
    ax1.set_xlabel('Chromosome position (Mb)', fontsize=15)
    ax1.set_ylabel('Crossovers (100kb)', fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ticks = ax1.get_xticks() / 1000000
    ax1.set_xticklabels(ticks)
        
    chr_len = chr_data["end"].iloc[-1]
    q1 =round(chr_len * 0.25 / 100000) * 100000
    q2 =round(chr_len* 0.50 / 100000) * 100000
    q3 =round(chr_len * 0.75 / 100000) * 100000

    ax1.axvline(x=q1, color='gray', linestyle='-')
    ax1.axvline(x=q2, color='gray', linestyle='--')
    ax1.axvline(x=q3, color='gray', linestyle='-')

    # Scatter plot
    scatter = ax2.scatter(chr_data.scrossovers, model_spreds, c='skyblue', edgecolors='black', linewidth= 0.3)
    ax2.set_title('Crossovers  vs. Prediction', fontsize=15)
    ax2.set_xlabel('Crossovers ', fontsize=15)
    ax2.set_ylabel('Prediction', fontsize=15)

    # Calculate correlation coefficient, coefficient of determination, and Mean Squared Error
    corr_chr = np.corrcoef(chr_data.scrossovers, model_spreds)[0, 1]
    r2_chr = r2_score(chr_data.scrossovers, model_spreds)
    mse_chr = mean_squared_error(chr_data.scrossovers, model_spreds)

    # Calculate the aspect ratio based on the plot heights
    h1 = ax1.get_ylim()
    h2 = ax2.get_ylim()
    aspect_ratio = max(h1[1] - h1[0], h2[1] - h2[0]) / (max(h1[1], h2[1]) - min(h1[0], h2[0]))

    # Set the aspect ratio for the scatter plot only if it doesn't distort the square shape
    if aspect_ratio < 1:
        ax2.set_aspect('equal')

    # Display correlation coefficient, coefficient of determination, and Mean Squared Error as plain text
    globals()[f'corr_chr{chr_number}'] = corr_chr
    globals()[f'r2_chr{chr_number}'] = r2_chr
    globals()[f'mse_chr{chr_number}'] = mse_chr

    textstr = f'Correlation: {corr_chr:.3f}\nR-squared: {r2_chr:.3f}\nMSE: {mse_chr:.3f}'
    ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=12, verticalalignment='top', horizontalalignment='left')

    # Adjustments to align the heights of the two plots
    max_height = max(h1[1], h2[1])
    ax1.set_ylim([h1[0], max_height])
    ax2.set_ylim([h2[0], max_height])

    # Reduce the separation between the plots
    plt.subplots_adjust(wspace=0.13)
    plt.show()

# %%
# Predictions and graphs for all chromosomes
for chr_number in range(1, 13):
    plot_chromosome_results(chr_number)
    plt.show()

# %% [markdown]
# # Data compilation

# %%
corr = pd.DataFrame({'corr':[corr_chr1, corr_chr2, corr_chr3, corr_chr4, corr_chr5, corr_chr6,corr_chr7, corr_chr8, corr_chr9, corr_chr10, corr_chr11, corr_chr12]})
r2 = pd.DataFrame({'R^2':[r2_chr1, r2_chr2, r2_chr3, r2_chr4, r2_chr5, r2_chr6, r2_chr7, r2_chr8, r2_chr9, r2_chr10, r2_chr11, r2_chr12]})
mse = pd.DataFrame({'MSE':[mse_chr1, mse_chr2, mse_chr3, mse_chr4, mse_chr5, mse_chr6, mse_chr7, mse_chr8, mse_chr9, mse_chr10, mse_chr11, mse_chr12]})
index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9','chr10','chr11','chr12']})
table = pd.concat([index, corr, r2, mse], axis=1)
table
# Out:
#       chr      corr       R^2       MSE
# 0    chr1  0.822022  0.674828  0.012476
# 1    chr2  0.760119  0.376137  0.013069
# 2    chr3  0.872666  0.741073  0.009870
# 3    chr4  0.803947  0.607798  0.016885
# 4    chr5  0.778070  0.539908  0.015110
# 5    chr6  0.672664  0.428918  0.020863
# 6    chr7  0.816645  0.666154  0.017242
# 7    chr8  0.894197  0.796756  0.007851
# 8    chr9  0.911857  0.797546  0.011255
# 9   chr10  0.856173  0.727861  0.011152
# 10  chr11  0.801633  0.616102  0.018368
# 11  chr12  0.939824  0.821274  0.013876

# %% [markdown]
# # Correlations between predictions and original values by chromosome quartiles

# %%
corr_q1 = pd.DataFrame({'Q1':[corr_q1_chr1,corr_q1_chr2,corr_q1_chr3,corr_q1_chr4,corr_q1_chr5,corr_q1_chr6,corr_q1_chr7,corr_q1_chr8,corr_q1_chr9,corr_q1_chr10,corr_q1_chr11,corr_q1_chr12]})
corr_q2 = pd.DataFrame({'Q2':[corr_q2_chr1,corr_q2_chr2,corr_q2_chr3,corr_q2_chr4,corr_q2_chr5,corr_q2_chr6,corr_q2_chr7,corr_q2_chr8,corr_q2_chr9,corr_q2_chr10,corr_q2_chr11,corr_q2_chr12]})
corr_q3 = pd.DataFrame({'Q3':[corr_q3_chr1,corr_q3_chr2,corr_q3_chr3,corr_q3_chr4,corr_q3_chr5,corr_q3_chr6,corr_q3_chr7,corr_q3_chr8,corr_q3_chr9,corr_q3_chr10,corr_q3_chr11,corr_q3_chr12]})
corr_q4 = pd.DataFrame({'Q4':[corr_q4_chr1,corr_q4_chr2,corr_q4_chr3,corr_q4_chr4,corr_q4_chr5,corr_q4_chr6,corr_q4_chr7,corr_q4_chr8,corr_q4_chr9,corr_q4_chr10,corr_q4_chr11,corr_q4_chr12]})

index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9','chr10','chr11','chr12']})
q_corr = pd.concat([index, corr_q1, corr_q2, corr_q3, corr_q4], axis=1)
q_corr_styled = q_corr.style.background_gradient(cmap="PRGn", vmin=-1, vmax=1)
q_corr_styled.set_table_styles([{'selector': 'th',
                                'props': [('text-align', 'center')]}])
q_corr_styled
# Out:
# <style type="text/css">
# #T_dda88 th {
#   text-align: center;
# }
# #T_dda88_row0_col1 {
#   background-color: #0e5f29;
#   color: #f1f1f1;
# }
# #T_dda88_row0_col2 {
#   background-color: #b3e0ad;
#   color: #000000;
# }
# #T_dda88_row0_col3 {
#   background-color: #7bc17c;
#   color: #000000;
# }
# #T_dda88_row0_col4 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_dda88_row1_col1 {
#   background-color: #55aa5e;
#   color: #f1f1f1;
# }
# #T_dda88_row1_col2 {
#   background-color: #308a45;
#   color: #f1f1f1;
# }
# #T_dda88_row1_col3, #T_dda88_row11_col3 {
#   background-color: #328c47;
#   color: #f1f1f1;
# }
# #T_dda88_row1_col4 {
#   background-color: #419951;
#   color: #f1f1f1;
# }
# #T_dda88_row2_col1, #T_dda88_row11_col1 {
#   background-color: #075223;
#   color: #f1f1f1;
# }
# #T_dda88_row2_col2 {
#   background-color: #449b52;
#   color: #f1f1f1;
# }
# #T_dda88_row2_col3 {
#   background-color: #84c784;
#   color: #000000;
# }
# #T_dda88_row2_col4, #T_dda88_row10_col1 {
#   background-color: #358e48;
#   color: #f1f1f1;
# }
# #T_dda88_row3_col1 {
#   background-color: #054e20;
#   color: #f1f1f1;
# }
# #T_dda88_row3_col2 {
#   background-color: #f3eef3;
#   color: #000000;
# }
# #T_dda88_row3_col3 {
#   background-color: #e8d7e9;
#   color: #000000;
# }
# #T_dda88_row3_col4 {
#   background-color: #69b76d;
#   color: #f1f1f1;
# }
# #T_dda88_row4_col1 {
#   background-color: #66b56b;
#   color: #f1f1f1;
# }
# #T_dda88_row4_col2 {
#   background-color: #f5f2f5;
#   color: #000000;
# }
# #T_dda88_row4_col3 {
#   background-color: #78c07a;
#   color: #000000;
# }
# #T_dda88_row4_col4 {
#   background-color: #085424;
#   color: #f1f1f1;
# }
# #T_dda88_row5_col1 {
#   background-color: #63b368;
#   color: #f1f1f1;
# }
# #T_dda88_row5_col2 {
#   background-color: #f6f7f6;
#   color: #000000;
# }
# #T_dda88_row5_col3 {
#   background-color: #1f7b39;
#   color: #f1f1f1;
# }
# #T_dda88_row5_col4 {
#   background-color: #ebf4e8;
#   color: #000000;
# }
# #T_dda88_row6_col1 {
#   background-color: #1c7938;
#   color: #f1f1f1;
# }
# #T_dda88_row6_col2 {
#   background-color: #8dcc8b;
#   color: #000000;
# }
# #T_dda88_row6_col3 {
#   background-color: #f2f6f1;
#   color: #000000;
# }
# #T_dda88_row6_col4 {
#   background-color: #146b30;
#   color: #f1f1f1;
# }
# #T_dda88_row7_col1 {
#   background-color: #065022;
#   color: #f1f1f1;
# }
# #T_dda88_row7_col2 {
#   background-color: #efe6f0;
#   color: #000000;
# }
# #T_dda88_row7_col3 {
#   background-color: #cdebc7;
#   color: #000000;
# }
# #T_dda88_row7_col4 {
#   background-color: #247f3d;
#   color: #f1f1f1;
# }
# #T_dda88_row8_col1 {
#   background-color: #0b5826;
#   color: #f1f1f1;
# }
# #T_dda88_row8_col2 {
#   background-color: #5aae61;
#   color: #f1f1f1;
# }
# #T_dda88_row8_col3 {
#   background-color: #4ea359;
#   color: #f1f1f1;
# }
# #T_dda88_row8_col4 {
#   background-color: #11652d;
#   color: #f1f1f1;
# }
# #T_dda88_row9_col1 {
#   background-color: #12672e;
#   color: #f1f1f1;
# }
# #T_dda88_row9_col2 {
#   background-color: #90ce8d;
#   color: #000000;
# }
# #T_dda88_row9_col3 {
#   background-color: #ede2ee;
#   color: #000000;
# }
# #T_dda88_row9_col4 {
#   background-color: #177133;
#   color: #f1f1f1;
# }
# #T_dda88_row10_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_dda88_row10_col3 {
#   background-color: #156d31;
#   color: #f1f1f1;
# }
# #T_dda88_row10_col4 {
#   background-color: #26823e;
#   color: #f1f1f1;
# }
# #T_dda88_row11_col2 {
#   background-color: #9cd597;
#   color: #000000;
# }
# #T_dda88_row11_col4 {
#   background-color: #0a5625;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dda88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dda88_level0_col0" class="col_heading level0 col0" >chr</th>
#       <th id="T_dda88_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_dda88_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_dda88_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_dda88_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dda88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dda88_row0_col0" class="data row0 col0" >chr1</td>
#       <td id="T_dda88_row0_col1" class="data row0 col1" >0.897475</td>
#       <td id="T_dda88_row0_col2" class="data row0 col2" >0.348213</td>
#       <td id="T_dda88_row0_col3" class="data row0 col3" >0.512892</td>
#       <td id="T_dda88_row0_col4" class="data row0 col4" >0.186035</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dda88_row1_col0" class="data row1 col0" >chr2</td>
#       <td id="T_dda88_row1_col1" class="data row1 col1" >0.609736</td>
#       <td id="T_dda88_row1_col2" class="data row1 col2" >0.734245</td>
#       <td id="T_dda88_row1_col3" class="data row1 col3" >0.719033</td>
#       <td id="T_dda88_row1_col4" class="data row1 col4" >0.678107</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dda88_row2_col0" class="data row2 col0" >chr3</td>
#       <td id="T_dda88_row2_col1" class="data row2 col1" >0.938719</td>
#       <td id="T_dda88_row2_col2" class="data row2 col2" >0.669753</td>
#       <td id="T_dda88_row2_col3" class="data row2 col3" >0.488785</td>
#       <td id="T_dda88_row2_col4" class="data row2 col4" >0.712223</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dda88_row3_col0" class="data row3 col0" >chr4</td>
#       <td id="T_dda88_row3_col1" class="data row3 col1" >0.956863</td>
#       <td id="T_dda88_row3_col2" class="data row3 col2" >-0.052919</td>
#       <td id="T_dda88_row3_col3" class="data row3 col3" >-0.187148</td>
#       <td id="T_dda88_row3_col4" class="data row3 col4" >0.561690</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dda88_row4_col0" class="data row4 col0" >chr5</td>
#       <td id="T_dda88_row4_col1" class="data row4 col1" >0.566578</td>
#       <td id="T_dda88_row4_col2" class="data row4 col2" >-0.023591</td>
#       <td id="T_dda88_row4_col3" class="data row4 col3" >0.523126</td>
#       <td id="T_dda88_row4_col4" class="data row4 col4" >0.930738</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dda88_row5_col0" class="data row5 col0" >chr6</td>
#       <td id="T_dda88_row5_col1" class="data row5 col1" >0.571479</td>
#       <td id="T_dda88_row5_col2" class="data row5 col2" >0.006571</td>
#       <td id="T_dda88_row5_col3" class="data row5 col3" >0.781307</td>
#       <td id="T_dda88_row5_col4" class="data row5 col4" >0.082875</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dda88_row6_col0" class="data row6 col0" >chr7</td>
#       <td id="T_dda88_row6_col1" class="data row6 col1" >0.789829</td>
#       <td id="T_dda88_row6_col2" class="data row6 col2" >0.462523</td>
#       <td id="T_dda88_row6_col3" class="data row6 col3" >0.034855</td>
#       <td id="T_dda88_row6_col4" class="data row6 col4" >0.849267</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dda88_row7_col0" class="data row7 col0" >chr8</td>
#       <td id="T_dda88_row7_col1" class="data row7 col1" >0.948269</td>
#       <td id="T_dda88_row7_col2" class="data row7 col2" >-0.095252</td>
#       <td id="T_dda88_row7_col3" class="data row7 col3" >0.246845</td>
#       <td id="T_dda88_row7_col4" class="data row7 col4" >0.767833</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dda88_row8_col0" class="data row8 col0" >chr9</td>
#       <td id="T_dda88_row8_col1" class="data row8 col1" >0.918506</td>
#       <td id="T_dda88_row8_col2" class="data row8 col2" >0.597654</td>
#       <td id="T_dda88_row8_col3" class="data row8 col3" >0.633286</td>
#       <td id="T_dda88_row8_col4" class="data row8 col4" >0.871273</td>
#     </tr>
#     <tr>
#       <th id="T_dda88_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dda88_row9_col0" class="data row9 col0" >chr10</td>
#       <td id="T_dda88_row9_col1" class="data row9 col1

# %% [markdown]
# # Save model performance metrics

# %%
table.to_csv('./output/performance_model_trained_in_pimpinellifolium_to_predict_in_lycopersicum_kmers.csv', index = None)
